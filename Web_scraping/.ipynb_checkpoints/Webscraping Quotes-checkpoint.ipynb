# %%
import requests
import bs4

# %%
r = requests.get('https://www.brainyquote.com/topics/motivational-quotes')

# %%
soup = bs4.BeautifulSoup(r.text)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Motivational Quotes - BrainyQuote
#   </title>
#   <meta content="all" name="robots"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0, viewport-fit=cover" name="viewport"/>
#   <meta content="Explore 274 Motivational Quotes by authors including Elon Musk, Eleanor Roosevelt, and Nelson Mandela at BrainyQuote." name="description"/>
#   <meta content="NOODP" name="googlebot"/>
#   <meta content="12.3.5:4463282" property="ver"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="none" name="msapplication-config"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="1627504500" property="ts"/>
#   <meta content="BrainyQuote" property="og:site_name"/>
#   <meta content="Motivational Quotes - BrainyQuote" property="og:title"/>
#   <meta content="article" property="og:type"/>
#   <meta content="Explore 274 Motivational Quotes by authors including Elon Musk, Eleanor Roosevelt, and Nelson Mandela at BrainyQuote." property="og:description"/>
#   <meta content="https://www.brainyquote.com/images/fbl.jpg" property="og:image"/>
#   <meta content="image/jpeg" property="og:image:type"/>
#   <meta content="200" property="og:image:width"/>
#   <meta content="200" property="og:image:height"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@BrainyQuote" name="twitter:site"/>
#   <meta content="916307096" name="twitter:app:id:iphone"/>
#   <meta content="916307096" name="twitter:app:id:ipad"/>
#   <meta content="@BrainyQuote" name="twitter:creator"/>
#   <meta content="Motivational Quotes" name="twitter:title"/>
#   <meta content="&quot;Good, better, best. Never let it rest. 'Til your good is better and your better is best.&quot; - St. Jerome" name="twitter:description"/>
#   <meta content="https://www.brainyquote.com/photos_tr/en/s/stjerome/389605/stjerome1.jpg" name="twitter:image"/>
#   <meta content="https://www.brainyquote.com/topics/motivational-quotes" property="og:url"/>
#   <link href="https://www.brainyquote.com/topics/motivational-quotes" rel="canonical"/>
#   <meta content="app-id=916307096" name="apple-itunes-app"/>
#   <link href="https://www.brainyquote.com/topics/motivational-quotes_2" rel="next"/>
#   <link href="/favicon.ico?cbv=3" rel="icon" type="image/x-icon"/>
#   <link href="/favicon.ico?cbv=3" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <meta content="BrainyQuote" name="apple-mobile-web-app-title"/>
#   <meta content="BrainyQuote" name="application-name"/>
#   <meta content="#2b5797" name="msapplication-TileColor"/>
#   <meta content="/mstile-144x144.png" name="msapplication-TileImage"/>
#   <meta content="/browserconfig.xml" name="msapplication-config"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <link href="/st/css/4463282/ws_l_q.css" media="screen, print" rel="stylesheet" type="text/css"/>
#   <script>
#    JsLOG = [];
# document.BQ_START = new Date().getTime();
# window.infoRevn = {adMargin:900,allAdPages:6,auctTimeoutAdmin:1000,bidDivs:false,ctTarg:{"bq_ct":"t","bq_pg":"f","bq_tId":"132622"},ddBullfrog:false,ddTLog:false,delayAuctionMargin:1100,firstInfScrollPos:3,forcebdrp:null,gaDisabledBasedOnPageType:false,infScrollSlotsPerAuction:2,infScrollSpacing:6,intlDrp:5,logPn:false,maxBidEnabled:true,maxBidMult:150,pbSyncDelay:3000,pbSyncsPerBidder:5,pubcid:true,revnOn:true,tadpole:false,usDrp:10};
# window.infoSvr = {RID:"4463282",country:"US",isAws:true,isDev:false,isLocal:false,isProd:true,region:"US",svrUID:"i-04c97a10ea00b6d63",svrVersion:"12.3.5:4463282"};
# window.infoReq = {abgrp:"b",cpageNum:1,curl:"/topics/motivational-quotes",domainId:"t:132622",gaPageType:"topic",langc:"en",lpageNum:5,ngmods:[],vid:"01150165525bfd366de8746d8c3477ea"};
# window.infoUI = {asyncScripts:["later"],delayedScripts:["kgj2PQz45pb347"],infEnabled:false,infLdMargin:1200,pageUsesGrid:true,pageUsesGridOnly:false,redirDom:true};
# document.BQ_ADCFG = {"procfg":{"appnexus":{"adj":"0.99"},"indexExchange":{"adj":"0.98"},"openx":{"adj":"1.0","sync":true},"pubmatic":{"adj":"0.96","sync":true},"sovrn":{"adj":"0.98"},"rubicon":{"adj":"0.99"},"criteo":{"adj":"0.98"}},"placements":[{"elementId":"div-gpt-ad-1418667263920-4","sizes":[[300,250],[1,1]],"masonryUseAllowed":true,"name":"/1008298/BQ_ros_square_300x250","sn":"sqT","bdrs":{"criteo":{"uf":false,"bfp":0,"zoneIds":[1320648],"adj":0.98},"appnexus":{"uf":true,"bfp":0,"plid":6524299,"adj":0.99},"pubmatic":{"uf":true,"bfp":0,"pubmaticName":"Square"},"rubicon":{"uf":true,"bfp":0,"zone":457864,"sizekey":15,"pos":"atf","adj":0.99},"openx":{"uf":true,"bfp":0,"oxAdUnitId":538124062},"sovrn":{"uf":true,"bfp":0,"tags":[{"tagName":"Header_BQ_ros_square_300x250","tagId":335425,"width":300,"height":250}]},"indexExchange":{"uf":true,"bfp":0,"tags":[{"tagName":"IE_Desktop_top_2","tagId":175234,"tagNum":2,"width":300,"height":250}]}},"hbSizes":[[300,250]]},{"elementId":"div-gpt-ad-1418667263920-3","sizes":[[300,250],[1,1]],"masonryUseAllowed":true,"name":"/1008298/BQ_ros_middle_300x250","sn":"sqM","bdrs":{"criteo":{"uf":false,"bfp":0,"zoneIds":[1320647],"adj":0.98},"appnexus":{"uf":true,"bfp":0,"plid":6524304,"adj":0.99},"pubmatic":{"uf":true,"bfp":0,"pubmaticName":"Middle"},"rubicon":{"uf":true,"bfp":0,"zone":457866,"sizekey":15,"pos":"atf","adj":0.99},"openx":{"uf":true,"bfp":0,"oxAdUnitId":538124063},"sovrn":{"uf":true,"bfp":0,"tags":[{"tagName":"Header_BQ_ros_middle_300x250","tagId":335426,"width":300,"height":250}]},"indexExchange":{"uf":true,"bfp":0,"tags":[{"tagName":"IE_Desktop_mid_5","tagId":175237,"tagNum":5,"width":300,"height":250}]}},"hbSizes":[[300,250]]},{"elementId":"div-gpt-ad-1418667263920-2","sizes":[[300,250],[1,1]],"masonryUseAllowed":false,"name":"/1008298/BQ_ros_center_300x250","sn":"sqC","bdrs":{"criteo":{"uf":false,"bfp":0,"zoneIds":[1320646],"adj":0.98},"appnexus":{"uf":true,"bfp":0,"plid":6524307,"adj":0.99},"pubmatic":{"uf":true,"bfp":0,"pubmaticName":"Center"},"rubicon":{"uf":true,"bfp":0,"zone":457868,"sizekey":15,"altsizekey":10,"pos":"atf","adj":0.99},"openx":{"uf":true,"bfp":0,"oxAdUnitId":538124064},"sovrn":{"uf":true,"bfp":0,"tags":[{"tagName":"Header_BQ_ros_center_300x250","tagId":335427,"width":300,"height":250}]},"indexExchange":{"uf":true,"bfp":0,"tags":[{"tagName":"IE_Desktop_center_6","tagId":175238,"tagNum":6,"width":300,"height":250}]}},"hbSizes":[[300,250]]},{"elementId":"div-gpt-ad-1418667263920-1","sizes":[[300,250],[1,1]],"masonryUseAllowed":true,"name":"/1008298/BQ_ros_bottom_300x250","sn":"sqB","bdrs":{"criteo":{"uf":false,"bfp":0,"zoneIds":[1320645],"adj":0.98},"appnexus":{"uf":true,"bfp":0,"plid":6524310,"adj":0.99},"pubmatic":{"uf":true,"bfp":0,"pubmaticName":"Bottom"},"rubicon":{"uf":true,"bfp":0,"zone":457870,"sizekey":15,"pos":"atf","adj":0.99},"openx":{"uf":true,"bfp":0,"oxAdUnitId":538124065},"sovrn":{"uf":true,"bfp":0,"tags":[{"tagName":"Header_BQ_ros_bottom_300x250","tagId":335428,"width":300,"height":250}]},"indexExchange":{"uf":true,"bfp":0,"tags":[{"tagName":"IE_Desktop_center_7","tagId":175239,"tagNum":7,"width":300,"height":250}]}},"hbSizes":[[300,250]]}],"curi":"/topics/motivational-quotes"};
# document.BQ_UNIT_LOOKUP = {"/1008298/BQ_ros_bottom_300x250":"div-gpt-ad-1418667263920-1","/1008298/BQ_ros_square_300x250":"div-gpt-ad-1418667263920-4","/1008298/BQ_ros_middle_300x250":"div-gpt-ad-1418667263920-3","/1008298/BQ_ros_center_300x250":"div-gpt-ad-1418667263920-2"};
# document.BQ_SLOTS = [["main","/1008298/BQ_ros_square_300x250","div-gpt-ad-1418667263920-4"],["main","/1008298/BQ_ros_middle_300x250","div-gpt-ad-1418667263920-3"],["mult_auct2","/1008298/BQ_ros_center_300x250","div-gpt-ad-1418667263920-2"],["mult_auct2","/1008298/BQ_ros_bottom_300x250","div-gpt-ad-1418667263920-1"],["mult_auct3","/1008298/BQ_ros_square_300x250","div-gpt-ad-1418667263920-4"],["mult_auct3","/1008298/BQ_ros_middle_300x250","div-gpt-ad-1418667263920-3"],["mult_auct4","/1008298/BQ_ros_center_300x250","div-gpt-ad-1418667263920-2"],["mb_footer","/1008298/BQ_ros_middle_300x250","div-gpt-ad-1418667263920-3"]];
# document.BQ_FOOTER_SLOTS = [];
#   </script>
#   <script defer="" src="/st/js/4463282/bq_first.js">
#   </script>
#   <script async="" src="/cdn-cgi/bm/cv/669835187/api.js">
#   </script>
#  </head>
#  <body class="qll-new is-grid-md gr-li-h">
#   <nav>
#    <div id="bqNavBarCtrl">
#     <div class="bq-tnav navbar" id="bq-tn-id">
#      <div class="bq-bluebar" style="line-height:10px">
#       <div class="bq-tnav-right grid-layout-hide" id="bq-tnav-hide">
#        <a aria-label="Search" class="bq-tnav-btn bq-nav-search-icon" href="/search">
#         <img alt="Search" aria-hidden="true" class="s-btn bq-fa-invert" src="/st/img/4463282/fa/search.svg"/>
#        </a>
#        <div class="bq-nav-search-form">
#         <form action="/search_results" autocomplete="off" class="no-border bq-no-print form-search" style="padding-left:8px; padding-right:4px">
#          <div class="bq-search" role="search">
#           <input alt="Submit Form" aria-label="Search" class="s-btn bq-fa" src="/st/img/4463282/fa/search.svg" type="image"/>
#           <input aria-label="Search on BrainyQuote" autocapitalize="off" class="s-fld-t input-medium search-query s-small" id="bq-search-input" maxlength="80" name="q" placeholder="search" spellcheck="false" type="text" value=""/>
#          </div>
#         </form>
#        </div>
#        <div class="nav-item dropdown bq-hamc" style="right: 0">
#         <a aria-expanded="false" aria-label="Menu" class="bq-tnav-btn bars dropdown-toggle" data-bs-toggle="dropdown" href="#">
#          <img alt="Menu" class="bq-fa-invert" src="/st/img/4463282/fa/bars.svg"/>
#         </a>
#         <div class="bq-right-menu hamburger-items dropdown-menu dropdown-menu-end">
#          <div class="bq-ham-ctr">
#           <div class="row bq-ham-m">
#            <div class="col-6 bq-rm-col">
#             <div class="tn-small-header">
#              Site
#             </div>
#             <div class="dropdown-item bq-ni">
#              <a href="/">
#               Home
#              </a>
#             </div>
#             <div class="dropdown-item bq-ni">
#              <a href="/authors">
#               Authors
#              </a>
#             </div>
#             <div class="dropdown-item bq-ni">
#              <a href="/topics">
#               Topics
#              </a>
#             </div>
#             <div class="dropdown-item bq-ni">
#              <a href="/quote_of_the_day">
#               Quote Of The Day
#              </a>
#             </div>
#             <div class="dropdown-item bq-ni">
#              <a href="/top_100_quotes">
#               Top 100 Quotes
#              </a>
#             </div>
#             <div class="dropdown-item bq-ni">
#              <a href="/profession/">
#               Professions
#              </a>
#             </div>
#             <div class="dropdown-item bq-ni">
#              <a href="/birthdays/">
#               Birthdays
#              </a>
#             </div>
#            </div>
#            <div class="col-6 bq-rm-col">
#             <div class="tn-small-header">
#              About
#             </div>
#             <div class="dropdown-item bq-ni">
#              <a href="/about/">
#               About Us
#              </a>
#             </div>
#             <div class="dropdown-item bq-ni">
#              <a href="/about/contact_us">
#               Contact Us
#              </a>
#             </div>
#             <div class="dropdown-item bq-ni">
#              <a href="/about/terms">
#               Terms Of Service
#              </a>
#             </div>
#             <div class="dropdown-item bq-ni">
#              <a href="/about/privacy">
#               Privacy Policy
#              </a>
#             </div>
#            </div>
#            <div class="col-12 bq-right-menu-footer">
#             <a class="bq-copyr" href="/about/copyright">
#              Copyright
#             </a>
#             © 2001 - 2021 BrainyQuote
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <a aria-label="Home Page" class="brand" href="/" style="padding:0px 5px 0px 15px; color:white">
#        <span class="bqLogo">
#        </span>
#       </a>
#       <div class="bq-nav-search-form sm-mbl hide-on-landscape">
#        <form action="/search_results" autocomplete="off" class="no-border bq-no-print form-search" style="padding-left:8px; padding-right:4px">
#         <div class="bq-search" role="search">
#          <input alt="Submit Form" aria-label="Search" class="s-btn bq-fa" src="/st/img/4463282/fa/search.svg" type="image"/>
#          <input aria-label="Search on BrainyQuote" autocapitalize="off" class="s-fld-t input-medium search-query s-small" id="bq-search-input-mbl-por" maxlength="80" name="q" placeholder="search" spellcheck="false" type="text" value=""/>
#         </div>
#        </form>
#       </div>
#       <ul class="nav navbar-nav hidden-xs" style="float:none; max-height:40px; overflow-y:hidden; display:inline-block">
#        <li class="bq-ni nav-item">
#         <a class="txnav nav-link" href="/">
#          Home
#         </a>
#        </li>
#        <li class="bq-ni nav-item">
#         <a class="txnav nav-link" href="/authors">
#          Authors
#         </a>
#        </li>
#        <li class="bq-ni nav-item active">
#         <a class="txnav nav-link" href="/topics">
#          Topics
#         </a>
#        </li>
#        <li class="bq-ni nav-item">
#         <a class="txnav nav-link" href="/quote_of_the_day">
#          Quote Of The Day
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="bq-subnav">
#      <div class="navbar bq-navbar" style="margin-left:0; margin-right:0">
#       <div class="navbar-header">
#        <h1 class="bq-subnav-h1">
#         Motivational Quotes
#        </h1>
#       </div>
#       <div class="r_dt grid-layout-hide" id="bq-subnav-hide">
#        <ul class="nav navbar-right hidden-1col">
#         <li class="hidden-1col dropdown">
#          <a aria-expanded="false" aria-haspopup="true" aria-label="Popular Authors" class="dropdown-toggle" data-bs-toggle="dropdown" href="#" role="button">
#           Popular Authors
#           <span class="caret">
#           </span>
#          </a>
#          <ul class="dropdown-menu dropdown-menu-end">
#           <li class="dropdown-item">
#            <a class="bq_on_link_cl" data-xtracl="PA,SubMenu,1" href="/authors/mark-twain-quotes">
#             Mark Twain
#            </a>
#           </li>
#           <li class="dropdown-item">
#            <a class="bq_on_link_cl" data-xtracl="PA,SubMenu,2" href="/authors/winston-churchill-quotes">
#             Winston Churchill
#            </a>
#           </li>
#           <li class="dropdown-item">
#            <a class="bq_on_link_cl" data-xtracl="PA,SubMenu,3" href="/authors/oscar-wilde-quotes">
#             Oscar Wilde
#            </a>
#           </li>
#           <li class="dropdown-item">
#            <a class="bq_on_link_cl" data-xtracl="PA,SubMenu,4" href="/authors/henry-david-thoreau-quotes">
#             Henry David Thoreau
#            </a>
#           </li>
#           <li class="dropdown-item">
#            <a class="bq_on_link_cl" data-xtracl="PA,SubMenu,5" href="/authors/ralph-waldo-emerson-quotes">
#             Ralph Waldo Emerson
#            </a>
#           </li>
#           <li class="dropdown-item">
#            <a class="bq_on_link_cl" data-xtracl="PA,SubMenu,6" href="/authors/ronald-reagan-quotes">
#             Ronald Reagan
#            </a>
#           </li>
#           <li class="dropdown-item">
#            <a class="bq_on_link_cl" data-xtracl="PA,SubMenu,7" href="/authors/thomas-sowell-quotes">
#             Thomas Sowell
#            </a>
#           </li>
#           <li class="dropdown-item">
#            <a class="bq_on_link_cl" data-xtracl="PA,SubMenu,8" href="/authors/confucius-quotes">
#             Confucius
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="hidden-1col dropdown">
#          <a aria-expanded="false" aria-haspopup="true" aria-label="Menu" class="dropdown-toggle" data-bs-toggle="dropdown" href="#" role="button">
#           Menu
#           <span class="caret">
#           </span>
#          </a>
#          <ul class="dropdown-menu dropdown-menu-end">
#           <li class="dropdown-item">
#            <a href="/lists/topics/top-10-motivational-quotes">
#             Top 10 Motivational Quotes
#            </a>
#           </li>
#           <li class="dropdown-item">
#            <a href="/citation/topics/motivational-quotes">
#             Cite this page
#            </a>
#           </li>
#           <li aria-hidden="true" class="divider" role="separator">
#           </li>
#           <li class="dropdown-header">
#            Layout
#           </li>
#           <li class="dropdown-item">
#            <a href="/topics/motivational-quotes" onclick="document.cookieUtils.setGridMode();return true;">
#             <i class="bq_grid bq-fa-th">
#             </i>
#             Grid
#            </a>
#           </li>
#           <li class="dropdown-item">
#            <a href="/topics/motivational-quotes" onclick="document.cookieUtils.setListMode();return true;">
#             <i class="bq_list bq-fa-list">
#             </i>
#             List
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a aria-label="Share on Facebook" class="sh-fb sh-grey" href="/share/fb/u?url=%2Ftopics%2Fmotivational-quotes" rel="nofollow" target="_blank">
#           <img alt="Share on Facebook" aria-hidden="true" class="bq-fa-sm" src="/st/img/4463282/fa/fb.svg"/>
#          </a>
#         </li>
#         <li>
#          <a aria-label="Share on Twitter" class="sh-tw sh-grey" href="/share/tw/u?url=%2Ftopics%2Fmotivational-quotes&amp;ti=Motivational+Quotes" rel="nofollow" target="_blank">
#           <img alt="Share on Twitter" aria-hidden="true" class="bq-fa-sm" src="/st/img/4463282/fa/tw.svg"/>
#          </a>
#         </li>
#         <li>
#          <a aria-label="Share on LinkedIn" class="sh-tw sh-grey" href="/share/li/u?url=%2Ftopics%2Fmotivational-quotes&amp;ti=Motivational+Quotes+-+BrainyQuote" rel="nofollow" target="_blank">
#           <img alt="Share on LinkedIn" aria-hidden="true" class="bq-fa-sm" src="/st/img/4463282/fa/li.svg"/>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="bq-nav-spacer">
#    </div>
#    <noscript>
#     <div class="enableJs">
#      <b>
#       Please enable Javascript
#      </b>
#      <br/>
#      This site requires Javascript to function properly, please enable it.
#     </div>
#    </noscript>
#   </nav>
#   <main>
#    <div class="bq-top-spc r_dt">
#    </div>
#    <div class="bq-mg bqcpx grid-layout-hide reflow_body bq_center ql_page" id="quotesList">
#     <div class="qbcol-c">
#      <div class="qbcol qbc-spc" id="qbc1">
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_1">
#        <a class="b-qt qt_389605 oncl_q" href="/quotes/st_jerome_389605?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Good, better, best. Never let it rest. 'Til your good is better and your better is best.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_389605 oncl_a" href="/authors/st-jerome-quotes" title="view author">
#         St. Jerome
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_2">
#        <a class="b-qt qt_378967 oncl_q" href="/quotes/nelson_mandela_378967?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          It always seems impossible until it's done.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_378967 oncl_a" href="/authors/nelson-mandela-quotes" title="view author">
#         Nelson Mandela
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_3">
#        <a class="b-qt qt_388332 oncl_q" href="/quotes/charles_r_swindoll_388332?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Life is 10% what happens to you and 90% how you react to it.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_388332 oncl_a" href="/authors/charles-r-swindoll-quotes" title="view author">
#         Charles R. Swindoll
#        </a>
#       </div>
#       <div class="m-ad-brick grid-item m-ad-minh boxy-ad" id="pos_1_4">
#        <div class="mbl_qtbox bq_300x250_edge" id="div-gpt-ad-1418667263920-4_edge">
#         <div class="bq_ad_320x250_multi bqAdCollapse" id="div-gpt-ad-1418667263920-4">
#         </div>
#        </div>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_5">
#        <a class="b-qt qt_371527 oncl_q" href="/quotes/arthur_ashe_371527?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Start where you are. Use what you have. Do what you can.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_371527 oncl_a" href="/authors/arthur-ashe-quotes" title="view author">
#         Arthur Ashe
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_6">
#        <a class="b-qt qt_567219 oncl_q" href="/quotes/elon_musk_567219?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          When something is important enough, you do it even if the odds are not in your favor.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_567219 oncl_a" href="/authors/elon-musk-quotes" title="view author">
#         Elon Musk
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_7">
#        <div class="qti-listm">
#         <a class="oncl_q" href="/quotes/eleanor_roosevelt_143006?src=t_motivational" title="view quote">
#          <img alt="With the new day comes new strength and new thoughts. - Eleanor Roosevelt" class="bqphtgrid" id="qimage_143006" src="/photos_tr/en/e/eleanorroosevelt/143006/eleanorroosevelt1.jpg"/>
#         </a>
#        </div>
#        <a class="b-qt qt_143006 oncl_q" href="/quotes/eleanor_roosevelt_143006?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          With the new day comes new strength and new thoughts.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_143006 oncl_a" href="/authors/eleanor-roosevelt-quotes" title="view author">
#         Eleanor Roosevelt
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_8">
#        <a class="b-qt qt_121335 oncl_q" href="/quotes/samuel_beckett_121335?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Ever tried. Ever failed. No matter. Try Again. Fail again. Fail better.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_121335 oncl_a" href="/authors/samuel-beckett-quotes" title="view author">
#         Samuel Beckett
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_9">
#        <a class="b-qt qt_371189 oncl_q" href="/quotes/carol_burnett_371189?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Only I can change my life. No one can do it for me.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_371189 oncl_a" href="/authors/carol-burnett-quotes" title="view author">
#         Carol Burnett
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_10">
#        <a class="b-qt qt_166055 oncl_q" href="/quotes/sam_levenson_166055?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Don't watch the clock; do what it does. Keep going.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_166055 oncl_a" href="/authors/sam-levenson-quotes" title="view author">
#         Sam Levenson
#        </a>
#       </div>
#       <div class="m-ad-brick grid-item m-ad-minh boxy-ad" id="pos_1_11">
#        <div class="mbl_qtbox bq_300x250_edge" id="div-gpt-ad-1418667263920-3_edge">
#         <div class="bq_ad_320x250_multi bqAdCollapse" id="div-gpt-ad-1418667263920-3">
#         </div>
#        </div>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_12">
#        <a class="b-qt qt_130027 oncl_q" href="/quotes/walt_disney_130027?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          If you can dream it, you can do it.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_130027 oncl_a" href="/authors/walt-disney-quotes" title="view author">
#         Walt Disney
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_13">
#        <a class="b-qt qt_137807 oncl_q" href="/quotes/w_clement_stone_137807?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Aim for the moon. If you miss, you may hit a star.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_137807 oncl_a" href="/authors/w-clement-stone-quotes" title="view author">
#         W. Clement Stone
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt" id="pos_1_14">
#        <a class="b-qt qt_165075 oncl_q" href="/quotes/jim_rohn_165075?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          If you don't design your own life plan, chances are you'll fall into someone else's plan. And guess what they have planned for you? Not much.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_165075 oncl_a" href="/authors/jim-rohn-quotes" title="view author">
#         Jim Rohn
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_15">
#        <a class="b-qt qt_134461 oncl_q" href="/quotes/john_d_rockefeller_134461?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          If you want to succeed you should strike out on new paths, rather than travel the worn paths of accepted success.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_134461 oncl_a" href="/authors/john-d-rockefeller-quotes" title="view author">
#         John D. Rockefeller
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_16">
#        <a class="b-qt qt_124452 oncl_q" href="/quotes/ken_venturi_124452?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          I don't believe you have to be better than everybody else. I believe you have to be better than you ever thought you could be.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_124452 oncl_a" href="/authors/ken-venturi-quotes" title="view author">
#         Ken Venturi
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_17">
#        <a class="b-qt qt_138200 oncl_q" href="/quotes/george_s_patton_138200?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          A good plan violently executed now is better than a perfect plan executed next week.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_138200 oncl_a" href="/authors/george-s-patton-quotes" title="view author">
#         George S. Patton
#        </a>
#       </div>
#       <div class="m-ad-brick grid-item m-ad-minh boxy-ad" id="pos_1_18">
#        <div class="mbl_qtbox bq_300x250_edge" id="div-gpt-ad-1418667263920-2-mult_auct2_edge">
#         <div class="bq_ad_320x250_multi bqAdCollapse" id="div-gpt-ad-1418667263920-2-mult_auct2">
#         </div>
#        </div>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_19">
#        <a class="b-qt qt_107067 oncl_q" href="/quotes/robert_h_schuller_107067?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Problems are not stop signs, they are guidelines.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_107067 oncl_a" href="/authors/robert-h-schuller-quotes" title="view author">
#         Robert H. Schuller
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_20">
#        <a class="b-qt qt_161315 oncl_q" href="/quotes/johann_wolfgang_von_goeth_161315?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Knowing is not enough; we must apply. Willing is not enough; we must do.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_161315 oncl_a" href="/authors/johann-wolfgang-von-goeth-quotes" title="view author">
#         Johann Wolfgang von Goethe
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_21">
#        <a class="b-qt qt_379604 oncl_q" href="/quotes/aristotle_379604?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Quality is not an act, it is a habit.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_379604 oncl_a" href="/authors/aristotle-quotes" title="view author">
#         Aristotle
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_22">
#        <a class="b-qt qt_149611 oncl_q" href="/quotes/simone_de_beauvoir_149611?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Change your life today. Don't gamble on the future, act now, without delay.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_149611 oncl_a" href="/authors/simone-de-beauvoir-quotes" title="view author">
#         Simone de Beauvoir
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_23">
#        <a class="b-qt qt_120259 oncl_q" href="/quotes/nikos_kazantzakis_120259?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          In order to succeed, we must first believe that we can.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_120259 oncl_a" href="/authors/nikos-kazantzakis-quotes" title="view author">
#         Nikos Kazantzakis
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_24">
#        <a class="b-qt qt_378036 oncl_q" href="/quotes/dalai_lama_378036?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Be kind whenever possible. It is always possible.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_378036 oncl_a" href="/authors/dalai-lama-quotes" title="view author">
#         Dalai Lama
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt" id="pos_1_25">
#        <a class="b-qt qt_120326 oncl_q" href="/quotes/pauline_kael_120326?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Where there is a will, there is a way. If there is a chance in a million that you can do something, anything, to keep what you want from ending, do it. Pry the door open or, if need be, wedge your foot in that door and keep it open.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_120326 oncl_a" href="/authors/pauline-kael-quotes" title="view author">
#         Pauline Kael
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_26">
#        <div class="qti-listm">
#         <a class="oncl_q" href="/quotes/aldous_huxley_386738?src=t_motivational" title="view quote">
#          <img alt="There is only one corner of the universe you can be certain of improving, and that's your own self. - Aldous Huxley" class="bqphtgrid bqDelay" data-img-url="/photos_tr/en/a/aldoushuxley/386738/aldoushuxley1.jpg" height="315" id="qimage_386738" src="/images/600x315.png" width="600"/>
#         </a>
#        </div>
#        <a class="b-qt qt_386738 oncl_q" href="/quotes/aldous_huxley_386738?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          There is only one corner of the universe you can be certain of improving, and that's your own self.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_386738 oncl_a" href="/authors/aldous-huxley-quotes" title="view author">
#         Aldous Huxley
#        </a>
#       </div>
#       <div class="m-ad-brick grid-item m-ad-minh boxy-ad" id="pos_1_27">
#        <div class="mbl_qtbox bq_300x250_edge" id="div-gpt-ad-1418667263920-1-mult_auct2_edge">
#         <div class="bq_ad_320x250_multi bqAdCollapse" id="div-gpt-ad-1418667263920-1-mult_auct2">
#         </div>
#        </div>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_28">
#        <a class="b-qt qt_129219 oncl_q" href="/quotes/bo_jackson_129219?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Set your goals high, and don't stop till you get there.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_129219 oncl_a" href="/authors/bo-jackson-quotes" title="view author">
#         Bo Jackson
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt" id="pos_1_29">
#        <a class="b-qt qt_410518 oncl_q" href="/quotes/bradley_whitford_410518?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Infuse your life with action. Don't wait for it to happen. Make it happen. Make your own future. Make your own hope. Make your own love. And whatever your beliefs, honor your creator, not by passively waiting for grace to come down from upon high, but by doing what you can to make grace happen... yourself, right now, right down here on Earth.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_410518 oncl_a" href="/authors/bradley-whitford-quotes" title="view author">
#         Bradley Whitford
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_30">
#        <a class="b-qt qt_163592 oncl_q" href="/quotes/h_g_wells_163592?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          If you fell down yesterday, stand up today.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_163592 oncl_a" href="/authors/h-g-wells-quotes" title="view author">
#         H. G. Wells
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_31">
#        <a class="b-qt qt_149102 oncl_q" href="/quotes/dwight_d_eisenhower_149102?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Motivation is the art of getting people to do what you want them to do because they want to do it.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_149102 oncl_a" href="/authors/dwight-d-eisenhower-quotes" title="view author">
#         Dwight D. Eisenhower
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_32">
#        <a class="b-qt qt_101840 oncl_q" href="/quotes/franklin_d_roosevelt_101840?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          When you reach the end of your rope, tie a knot in it and hang on.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_101840 oncl_a" href="/authors/franklin-d-roosevelt-quotes" title="view author">
#         Franklin D. Roosevelt
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_33">
#        <a class="b-qt qt_190719 oncl_q" href="/quotes/walter_elliot_190719?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Perseverance is not a long race; it is many short races one after the other.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_190719 oncl_a" href="/authors/walter-elliot-quotes" title="view author">
#         Walter Elliot
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_34">
#        <a class="b-qt qt_221770 oncl_q" href="/quotes/kyle_chandler_221770?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Opportunity does not knock, it presents itself when you beat down the door.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_221770 oncl_a" href="/authors/kyle-chandler-quotes" title="view author">
#         Kyle Chandler
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_35">
#        <a class="b-qt qt_157864 oncl_q" href="/quotes/og_mandino_157864?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Failure will never overtake me if my determination to succeed is strong enough.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_157864 oncl_a" href="/authors/og-mandino-quotes" title="view author">
#         Og Mandino
#        </a>
#       </div>
#       <div class="m-ad-brick grid-item m-ad-minh boxy-ad" id="pos_1_36">
#        <div class="mbl_qtbox bq_300x250_edge" id="div-gpt-ad-1418667263920-4-mult_auct3_edge">
#         <div class="bq_ad_320x250_multi bqAdCollapse" id="div-gpt-ad-1418667263920-4-mult_auct3">
#         </div>
#        </div>
#       </div>
#       <div class="grid-item qb clearfix bqQt" id="pos_1_37">
#        <a class="b-qt qt_109443 oncl_q" href="/quotes/pope_john_xxiii_109443?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Consult not your fears but your hopes and your dreams. Think not about your frustrations, but about your unfulfilled potential. Concern yourself not with what you tried and failed in, but with what it is still possible for you to do.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_109443 oncl_a" href="/authors/pope-john-xxiii-quotes" title="view author">
#         Pope John XXIII
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt" id="pos_1_38">
#        <a class="b-qt qt_627123 oncl_q" href="/quotes/stephen_hawking_627123?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Look up at the stars and not down at your feet. Try to make sense of what you see, and wonder about what makes the universe exist. Be curious.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_627123 oncl_a" href="/authors/stephen-hawking-quotes" title="view author">
#         Stephen Hawking
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_39">
#        <a class="b-qt qt_103788 oncl_q" href="/quotes/winston_churchill_103788?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          If you're going through hell, keep going.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_103788 oncl_a" href="/authors/winston-churchill-quotes" title="view author">
#         Winston Churchill
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_40">
#        <a class="b-qt qt_118964 oncl_q" href="/quotes/mark_twain_118964?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          The secret of getting ahead is getting started.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_118964 oncl_a" href="/authors/mark-twain-quotes" title="view author">
#         Mark Twain
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_41">
#        <a class="b-qt qt_101245 oncl_q" href="/quotes/william_blake_101245?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          No bird soars too high if he soars with his own wings.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_101245 oncl_a" href="/authors/william-blake-quotes" title="view author">
#         William Blake
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_42">
#        <a class="b-qt qt_119693 oncl_q" href="/quotes/helen_rowland_119693?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          You will never win if you never begin.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_119693 oncl_a" href="/authors/helen-rowland-quotes" title="view author">
#         Helen Rowland
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_43">
#        <a class="b-qt qt_122102 oncl_q" href="/quotes/mark_caine_122102?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          The first step toward success is taken when you refuse to be a captive of the environment in which you first find yourself.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_122102 oncl_a" href="/authors/mark-caine-quotes" title="view author">
#         Mark Caine
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_44">
#        <a class="b-qt qt_103731 oncl_q" href="/quotes/benjamin_franklin_103731?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Well done is better than well said.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_103731 oncl_a" href="/authors/benjamin-franklin-quotes" title="view author">
#         Benjamin Franklin
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_45">
#        <div class="qti-listm">
#         <a class="oncl_q" href="/quotes/tom_stoppard_132715?src=t_motivational" title="view quote">
#          <img alt="Every exit is an entry somewhere else. - Tom Stoppard" class="bqphtgrid bqDelay" data-img-url="/photos_tr/en/t/tomstoppard/132715/tomstoppard1.jpg" height="315" id="qimage_132715" src="/images/600x315.png" width="600"/>
#         </a>
#        </div>
#        <a class="b-qt qt_132715 oncl_q" href="/quotes/tom_stoppard_132715?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Every exit is an entry somewhere else.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_132715 oncl_a" href="/authors/tom-stoppard-quotes" title="view author">
#         Tom Stoppard
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_46">
#        <a class="b-qt qt_340581 oncl_q" href="/quotes/george_lucas_340581?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          You simply have to put one foot in front of the other and keep going. Put blinders on and plow right ahead.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_340581 oncl_a" href="/authors/george-lucas-quotes" title="view author">
#         George Lucas
#        </a>
#       </div>
#       <div class="m-ad-brick grid-item m-ad-minh boxy-ad" id="pos_1_47">
#        <div class="mbl_qtbox bq_300x250_edge" id="div-gpt-ad-1418667263920-3-mult_auct3_edge">
#         <div class="bq_ad_320x250_multi bqAdCollapse" id="div-gpt-ad-1418667263920-3-mult_auct3">
#         </div>
#        </div>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_48">
#        <a class="b-qt qt_379468 oncl_q" href="/quotes/babe_ruth_379468?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          You just can't beat the person who never gives up.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_379468 oncl_a" href="/authors/babe-ruth-quotes" title="view author">
#         Babe Ruth
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_49">
#        <a class="b-qt qt_160088 oncl_q" href="/quotes/philip_sidney_160088?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Either I will find a way, or I will make one.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
# ...
#        <a class="bq-aut qa_147148 oncl_a" href="/authors/simone-weil-quotes" title="view author">
#         Simone Weil
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_60">
#        <a class="b-qt qt_193094 oncl_q" href="/quotes/joan_of_arc_193094?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          I am not afraid... I was born to do this.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_193094 oncl_a" href="/authors/joan-of-arc-quotes" title="view author">
#         Joan of Arc
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_61">
#        <a class="b-qt qt_236730 oncl_q" href="/quotes/dean_koontz_236730?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          I really believe that everyone has a talent, ability, or skill that he can mine to support himself and to succeed in life.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_236730 oncl_a" href="/authors/dean-koontz-quotes" title="view author">
#         Dean Koontz
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_62">
#        <a class="b-qt qt_165697 oncl_q" href="/quotes/wayne_dyer_165697?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Be miserable. Or motivate yourself. Whatever has to be done, it's always your choice.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_165697 oncl_a" href="/authors/wayne-dyer-quotes" title="view author">
#         Wayne Dyer
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_63">
#        <a class="b-qt qt_136001 oncl_q" href="/quotes/theodore_roosevelt_136001?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Keep your eyes on the stars, and your feet on the ground.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_136001 oncl_a" href="/authors/theodore-roosevelt-quotes" title="view author">
#         Theodore Roosevelt
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_64">
#        <div class="qti-listm">
#         <a class="oncl_q" href="/quotes/victor_kiam_120741?src=t_motivational" title="view quote">
#          <img alt="Even if you fall on your face, you're still moving forward. - Victor Kiam" class="bqphtgrid bqDelay" data-img-url="/photos_tr/en/v/victorkiam/120741/victorkiam1.jpg" height="315" id="qimage_120741" src="/images/600x315.png" width="600"/>
#         </a>
#        </div>
#        <a class="b-qt qt_120741 oncl_q" href="/quotes/victor_kiam_120741?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Even if you fall on your face, you're still moving forward.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_120741 oncl_a" href="/authors/victor-kiam-quotes" title="view author">
#         Victor Kiam
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_65">
#        <a class="b-qt qt_119899 oncl_q" href="/quotes/john_burroughs_119899?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Leap, and the net will appear.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_119899 oncl_a" href="/authors/john-burroughs-quotes" title="view author">
#         John Burroughs
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_66">
#        <a class="b-qt qt_109332 oncl_q" href="/quotes/alfred_a_montapert_109332?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Expect problems and eat them for breakfast.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_109332 oncl_a" href="/authors/alfred-a-montapert-quotes" title="view author">
#         Alfred A. Montapert
#        </a>
#       </div>
#       <div class="grid-item qb clearfix bqQt b-qt-lg" id="pos_1_67">
#        <a class="b-qt qt_105643 oncl_q" href="/quotes/william_james_105643?src=t_motivational" title="view quote">
#         <div style="display: flex;justify-content: space-between">
#          Act as if what you do makes a difference. It does.
#          <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4463282/fa/chv-r.svg"/>
#         </div>
#        </a>
#        <a class="bq-aut qa_105643 oncl_a" href="/authors/william-james-quotes" title="view author">
#         William James
#        </a>
#       </div>
#      </div>
#      <div class="qbcol qbc-spc" id="qbc2">
#      </div>
#      <div class="qbcol qbc-spc" id="qbc3">
#      </div>
#      <div class="qbcol qbc-spc" id="qbc4">
#      </div>
#      <div class="qbcol qbc-spc" id="qbc5">
#      </div>
#      <div class="qbcol qbc-spc" id="qbc6">
#      </div>
#     </div>
#    </div>
#    <div class="infScrollFooter">
#     <div class="bq_s hideInfScroll bq_pageNumbersCont">
#      <ul class="pagination bq_pageNumbers pagination-centered pagination-sm">
#       <li class="page-item disabled">
#        <span class="page-link">
#         Prev
#        </span>
#       </li>
#       <li class="page-item active">
#        <span class="page-link">
#         1
#        </span>
#       </li>
#       <li class="page-item">
#        <a class="page-link" href="/topics/motivational-quotes_2">
#         2
#        </a>
#       </li>
#       <li class="page-item">
#        <a class="page-link" href="/topics/motivational-quotes_3">
#         3
#        </a>
#       </li>
#       <li class="page-item">
#        <a class="page-link" href="/topics/motivational-quotes_4">
#         4
#        </a>
#       </li>
#       <li class="page-item">
#        <a class="page-link" href="/topics/motivational-quotes_5">
#         5
#        </a>
#       </li>
#       <li class="page-item">
#        <a class="page-link" href="/topics/motivational-quotes_2">
#         Next
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="bq_footer_ad">
#      <div class="mbl_qtbox bq_300x250_edge" id="div-gpt-ad-1418667263920-3-mb_footer_edge">
#       <div class="bq_ad_320x250_multi bqAdCollapse" id="div-gpt-ad-1418667263920-3-mb_footer">
#       </div>
#      </div>
#      <div style="height:20px;">
#      </div>
#     </div>
#     <div class="container-fluid" style="max-width:1350px;margin-top:25px;margin-bottom:25px;">
#      <div class="row">
#       <div class="col-12 block-style">
#        <div class="bq_s row">
#         <h2>
#          Recommended Topics
#         </h2>
#         <div class="col-lg-3 col-6 block-sm-holder">
#          <a class="block-sm bq_on_link_cl" data-xtracl="RT,Motivational,1" href="/topics/life-quotes">
#           <span class="link-name">
#            Life
#            <br/>
#            <span>
#             Quotes
#            </span>
#           </span>
#          </a>
#         </div>
#         <div class="col-lg-3 col-6 block-sm-holder">
#          <a class="block-sm bq_on_link_cl" data-xtracl="RT,Motivational,2" href="/topics/inspirational-quotes">
#           <span class="link-name">
#            Inspirational
#            <br/>
#            <span>
#             Quotes
#            </span>
#           </span>
#          </a>
#         </div>
#         <div class="col-lg-3 col-6 block-sm-holder">
#          <a class="block-sm bq_on_link_cl" data-xtracl="RT,Motivational,3" href="/topics/positive-quotes">
#           <span class="link-name">
#            Positive
#            <br/>
#            <span>
#             Quotes
#            </span>
#           </span>
#          </a>
#         </div>
#         <div class="col-lg-3 col-6 block-sm-holder">
#          <a class="block-sm bq_on_link_cl" data-xtracl="RT,Motivational,4" href="/topics/education-quotes">
#           <span class="link-name">
#            Education
#            <br/>
#            <span>
#             Quotes
#            </span>
#           </span>
#          </a>
#         </div>
#         <div class="col-lg-3 col-6 block-sm-holder">
#          <a class="block-sm bq_on_link_cl" data-xtracl="RT,Motivational,5" href="/topics/good-quotes">
#           <span class="link-name">
#            Good
#            <br/>
#            <span>
#             Quotes
#            </span>
#           </span>
#          </a>
#         </div>
#         <div class="col-lg-3 col-6 block-sm-holder">
#          <a class="block-sm bq_on_link_cl" data-xtracl="RT,Motivational,6" href="/topics/attitude-quotes">
#           <span class="link-name">
#            Attitude
#            <br/>
#            <span>
#             Quotes
#            </span>
#           </span>
#          </a>
#         </div>
#         <div class="col-lg-3 col-6 block-sm-holder">
#          <a class="block-sm bq_on_link_cl" data-xtracl="RT,Motivational,7" href="/topics/smile-quotes">
#           <span class="link-name">
#            Smile
#            <br/>
#            <span>
#             Quotes
#            </span>
#           </span>
#          </a>
#         </div>
#         <div class="col-lg-3 col-6 block-sm-holder">
#          <a class="block-sm bq_on_link_cl" data-xtracl="RT,Motivational,8" href="/topics/best-quotes">
#           <span class="link-name">
#            Best
#            <br/>
#            <span>
#             Quotes
#            </span>
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </main>
#   <footer>
#    <div id="bqBotNav">
#     <div class="bq_bot_nav bq-no-print">
#      <div class="container-fluid" style="max-width: 900px">
#       <div class="row">
#        <div class="col-sm-6 col-md-3 col-12">
#         <div class="bq_pinweel" style="float:left; position:absolute; top:-25px;">
#          <span class="bqPinweel">
#          </span>
#         </div>
#         <div style="height:75px">
#         </div>
#         <div class="bq_s">
#          <ul class="footer-follow-icons">
#           <li>
#            <a aria-label="Follow us on Facebook" href="https://www.facebook.com/BrainyQuote" rel="noreferrer" target="_blank">
#             <img alt="Share on Facebook" class="bq-fa-full" src="/st/img/4463282/fa/fb.svg"/>
#            </a>
#           </li>
#           <li>
#            <a aria-label="Follow us on Twitter" href="https://twitter.com/brainyquote" rel="noreferrer" target="_blank">
#             <img alt="Share on Twitter" class="bq-fa-full" src="/st/img/4463282/fa/tw.svg"/>
#            </a>
#           </li>
#           <li>
#            <a aria-label="Follow us on Pinterest" href="https://pinterest.com/brainyquote" rel="noreferrer" target="_blank">
#             <img alt="Share on Pinterest" class="bq-fa-full" src="/st/img/4463282/fa/pinterest.svg"/>
#            </a>
#           </li>
#           <li class="follow-padding-fix">
#            <a aria-label="Follow us on Instagram" href="https://instagram.com/brainyquote" rel="noreferrer" target="_blank">
#             <img alt="Share on Instagram" class="bq-fa-full" src="/st/img/4463282/fa/ig.svg"/>
#            </a>
#           </li>
#          </ul>
#          <div style="clear:both">
#          </div>
#         </div>
#        </div>
#        <div class="col-sm-6 col-md-3 col-12">
#         <div class="bq_s">
#          BrainyQuote has been providing inspirational quotes since 2001 to our worldwide community.
#         </div>
#         <div class="bq_s">
#          <h3>
#           Quote Of The Day Feeds
#          </h3>
#          <div class="bqLn">
#           <a href="/feeds/todays_quote">
#            Javascript and RSS feeds
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/feeds/wordpress_plugin">
#            WordPress plugin
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/feeds/quote_of_the_day_email">
#            Quote of the Day Email
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col-sm-6 col-md-2 col-12">
#         <div class="bq_s">
#          <h3>
#           Site
#          </h3>
#          <div class="bqLn">
#           <a href="/">
#            Home
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/authors">
#            Authors
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/topics">
#            Topics
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/quote_of_the_day">
#            Quote Of The Day
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/top_100_quotes">
#            Top 100 Quotes
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/profession/">
#            Professions
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/birthdays/">
#            Birthdays
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col-sm-6 col-md-2 col-12">
#         <div class="bq_s">
#          <h3>
#           About
#          </h3>
#          <div class="bqLn">
#           <a href="/about/">
#            About Us
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/about/contact_us">
#            Contact Us
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/about/privacy">
#            Privacy
#           </a>
#          </div>
#          <div class="bqLn">
#           <a href="/about/terms">
#            Terms
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col-sm-6 col-md-2 col-12">
#         <div class="bq_s">
#          <h3>
#           Apps
#          </h3>
#          <div class="bqLn">
#           <a href="/apps/">
#            iOS app
#           </a>
#          </div>
#          <br/>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="copyLangFooter langSelLink">
#      <div class="container">
#       <div class="row">
#        <div class="col-sm-5 col-md-5">
#         <div class="ftr_nav" style="vertical-align:center; padding-left: 15px">
#          <a href="/about/copyright" style="vertical-align:top">
#           Copyright
#          </a>
#          © 2001 - 2021 BrainyQuote
#         </div>
#        </div>
#        <div class="col-sm-5 col-md-5 usp-footer-hide" id="usp-c">
#         <div class="ftr_nav" id="usp-footer" style="vertical-align:center; padding-left: 15px;">
#          <a href="/ccpa">
#           Do Not Sell My Info
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <script type="application/ld+json">
#      {
# "@context": "http://schema.org",
# "@type": "WebSite",
# "url": "https://www.brainyquote.com/",
# "name": "BrainyQuote",
# "alternateName": "BrainyQuote - Famous Quotes",
# "potentialAction": {
# "@type": "SearchAction",
# "target": "https://www.brainyquote.com/search_results?q={search_term}",
# "query-input": "required name=search_term"
# }
# }
#     </script>
#     <script type="application/ld+json">
#      {
# "@context": "http://schema.org",
# "@type": "BreadcrumbList",
# "itemListElement": [
# {
# "item": {
# "name": "Quote Topics",
# "@id": "https://www.brainyquote.com/topics"
# },
# "@type": "ListItem",
# "position": 1
# },
# {
# "item": {
# "name": "Motivational Quotes",
# "@id": "https://www.brainyquote.com/topics/motivational-quotes"
# },
# "@type": "ListItem",
# "position": 2
# }
# ]
# }
#     </script>
#    </div>
#   </footer>
#   <script type="text/javascript">
#    (function(){window['__CF$cv$params']={r:'6760fe7059e23630',m:'30b88aac0d6f5e90fdb59f3bff16d9b8c3b2e230-1627505574-1800-AfSzv1haGowkQqxDPZXM5VUI7f4r8cVtheDCor9h8/Vcfm9N/gH6n9+mZhEHdhLPQoId6UehxsURcMOPSFBINoqu0dJWZnhcshvD4EMM6oP8fITNK6laU1pT4Ky4HdV4nrUs0Rq1ge0GwGXr0Tyc4TE=',s:[0x440b32416d,0xaf53cd16d9],}})();
#   </script>
#  </body>
# </html>

# %%
[x.text.strip() for x in soup.find('div', attrs={'id':'qbc1'}).find_all('a', attrs={'title':'view quote'}) if x.text.strip()]
# Out:
# ["Good, better, best. Never let it rest. 'Til your good is better and your better is best.",
#  "It always seems impossible until it's done.",
#  'Life is 10% what happens to you and 90% how you react to it.',
#  'Start where you are. Use what you have. Do what you can.',
#  'When something is important enough, you do it even if the odds are not in your favor.',
#  'With the new day comes new strength and new thoughts.',
#  'Ever tried. Ever failed. No matter. Try Again. Fail again. Fail better.',
#  'Only I can change my life. No one can do it for me.',
#  "Don't watch the clock; do what it does. Keep going.",
#  'If you can dream it, you can do it.',
#  'Aim for the moon. If you miss, you may hit a star.',
#  "If you don't design your own life plan, chances are you'll fall into someone else's plan. And guess what they have planned for you? Not much.",
#  'If you want to succeed you should strike out on new paths, rather than travel the worn paths of accepted success.',
#  "I don't believe you have to be better than everybody else. I believe you have to be better than you ever thought you could be.",
#  'A good plan violently executed now is better than a perfect plan executed next week.',
#  'Problems are not stop signs, they are guidelines.',
#  'Knowing is not enough; we must apply. Willing is not enough; we must do.',
#  'Quality is not an act, it is a habit.',
#  "Change your life today. Don't gamble on the future, act now, without delay.",
#  'In order to succeed, we must first believe that we can.',
#  'Be kind whenever possible. It is always possible.',
#  'Where there is a will, there is a way. If there is a chance in a million that you can do something, anything, to keep what you want from ending, do it. Pry the door open or, if need be, wedge your foot in that door and keep it open.',
#  "There is only one corner of the universe you can be certain of improving, and that's your own self.",
#  "Set your goals high, and don't stop till you get there.",
#  "Infuse your life with action. Don't wait for it to happen. Make it happen. Make your own future. Make your own hope. Make your own love. And whatever your beliefs, honor your creator, not by passively waiting for grace to come down from upon high, but by doing what you can to make grace happen... yourself, right now, right down here on Earth.",
#  'If you fell down yesterday, stand up today.',
#  'Motivation is the art of getting people to do what you want them to do because they want to do it.',
#  'When you reach the end of your rope, tie a knot in it and hang on.',
#  'Perseverance is not a long race; it is many short races one after the other.',
#  'Opportunity does not knock, it presents itself when you beat down the door.',
#  'Failure will never overtake me if my determination to succeed is strong enough.',
#  'Consult not your fears but your hopes and your dreams. Think not about your frustrations, but about your unfulfilled potential. Concern yourself not with what you tried and failed in, but with what it is still possible for you to do.',
#  'Look up at the stars and not down at your feet. Try to make sense of what you see, and wonder about what makes the universe exist. Be curious.',
#  "If you're going through hell, keep going.",
#  'The secret of getting ahead is getting started.',
#  'No bird soars too high if he soars with his own wings.',
#  'You will never win if you never begin.',
#  'The first step toward success is taken when you refuse to be a captive of the environment in which you first find yourself.',
#  'Well done is better than well said.',
#  'Every exit is an entry somewhere else.',
#  'You simply have to put one foot in front of the other and keep going. Put blinders on and plow right ahead.',
#  "You just can't beat the person who never gives up.",
#  'Either I will find a way, or I will make one.',
#  'Decide what you want, decide what you are willing to exchange for it. Establish your priorities and go to work.',
#  'Without hard work, nothing grows but weeds.',
#  'It does not matter how slowly you go as long as you do not stop.',
#  "I learned that we can do anything, but we can't do everything... at least not at the same time. So think of your priorities not in terms of what activities you do, but when you do them. Timing is everything.",
#  'By failing to prepare, you are preparing to fail.',
#  "The will to succeed is important, but what's more important is the will to prepare.",
#  'You can never quit. Winners never quit, and quitters never win.',
#  'Perseverance is failing 19 times and succeeding the 20th.',
#  'I can, therefore I am.',
#  'I am not afraid... I was born to do this.',
#  'I really believe that everyone has a talent, ability, or skill that he can mine to support himself and to succeed in life.',
#  "Be miserable. Or motivate yourself. Whatever has to be done, it's always your choice.",
#  'Keep your eyes on the stars, and your feet on the ground.',
#  "Even if you fall on your face, you're still moving forward.",
#  'Leap, and the net will appear.',
#  'Expect problems and eat them for breakfast.',
#  'Act as if what you do makes a difference. It does.']

# %%
[x.text for x in soup.find('div', attrs={'id':'qbc1'}).find_all('a', attrs={'title':'view author'})]
# Out:
# ['St. Jerome',
#  'Nelson Mandela',
#  'Charles R. Swindoll',
#  'Elon Musk',
#  'Arthur Ashe',
#  'Eleanor Roosevelt',
#  'Samuel Beckett',
#  'Carol Burnett',
#  'Sam Levenson',
#  'Walt Disney',
#  'John D. Rockefeller',
#  'W. Clement Stone',
#  'Jim Rohn',
#  'Ken Venturi',
#  'George S. Patton',
#  'Robert H. Schuller',
#  'Aristotle',
#  'Johann Wolfgang von Goethe',
#  'Simone de Beauvoir',
#  'Pauline Kael',
#  'Nikos Kazantzakis',
#  'Dwight D. Eisenhower',
#  'Dalai Lama',
#  'Aldous Huxley',
#  'Bo Jackson',
#  'H. G. Wells',
#  'Bradley Whitford',
#  'Walter Elliot',
#  'Franklin D. Roosevelt',
#  'Og Mandino',
#  'Stephen Hawking',
#  'Kyle Chandler',
#  'Pope John XXIII',
#  'William Blake',
#  'Winston Churchill',
#  'Mark Twain',
#  'Mark Caine',
#  'Benjamin Franklin',
#  'Tom Stoppard',
#  'Helen Rowland',
#  'George Lucas',
#  'Gordon B. Hinckley',
#  'Philip Sidney',
#  'H. L. Hunt',
#  'Simone Weil',
#  'Babe Ruth',
#  'Confucius',
#  'Benjamin Franklin',
#  'Dan Millman',
#  'John Burroughs',
#  'Joan of Arc',
#  'Wayne Dyer',
#  'Dean Koontz',
#  'Theodore Roosevelt',
#  'Ted Turner',
#  'Bobby Knight',
#  'Victor Kiam',
#  'Julie Andrews',
#  'William James',
#  'Alfred A. Montapert']

# %%
def get_links(start, end, base_link):
    lst_links =[]
    for i in range(start, end+1):
        if i == 1:
            lst_links.append(base_link)
        else:
            lst_links.append(base_link + '_' + str(i))
    return lst_links

# %%
get_links(1,5, 'https://www.brainyquote.com/topics/motivational-quotes')
# Out:
# ['https://www.brainyquote.com/topics/motivational-quotes',
#  'https://www.brainyquote.com/topics/motivational-quotes_2',
#  'https://www.brainyquote.com/topics/motivational-quotes_3',
#  'https://www.brainyquote.com/topics/motivational-quotes_4',
#  'https://www.brainyquote.com/topics/motivational-quotes_5']

# %%
def get_quotes(links):
    quotes = []
    authors = []
    for i in links:
        r = requests.get(i)
        soup = bs4.BeautifulSoup(r.text)
        quote = [x.text.strip() for x in soup.find('div', attrs={'id':'qbc1'}).find_all('a', attrs={'title':'view quote'}) if x.text.strip()]
        quotes = quotes + quote
        author =[x.text for x in soup.find('div', attrs={'id':'qbc1'}).find_all('a', attrs={'title':'view author'})]
        authors = authors + author
    return quotes, authors

# %%
a,b= get_quotes(get_links(1,5, 'https://www.brainyquote.com/topics/motivational-quotes'))

# %%
len(a)
# Out:
# 274

# %%
len(b)
# Out:
# 274
